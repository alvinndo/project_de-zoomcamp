# %%
import pandas as pd

# %%
df = pd.DataFrame(pd.read_excel("https://www.bls.gov/lau/laucnty05.xlsx"))

# %%
df.drop(index=df.index[:5], axis=0, inplace=True)

# %%
df.drop(index=df.tail(3).index,axis = 0, inplace=True)

# %%
df.drop(columns="Unnamed: 5", inplace=True)

# %%
df.replace(to_replace="N.A.", value=0, inplace=True)

# %%
df.columns = ["LAUS_code", "state_fips", "county_fips", "county_state", "year", "labor_force", "employed", "unemployed", "unemployment_rate"]

# %%
df['fips'] = df['state_fips'] + df['county_fips']

# %%
df
# Out:
#             LAUS_code state_fips county_fips             county_state  year  \
# 5     CN0100100000000         01         001       Autauga County, AL  2005
# 6     CN0100300000000         01         003       Baldwin County, AL  2005
# 7     CN0100500000000         01         005       Barbour County, AL  2005
# 8     CN0100700000000         01         007          Bibb County, AL  2005
# 9     CN0100900000000         01         009        Blount County, AL  2005
# ...               ...        ...         ...                      ...   ...
# 3217  CN7214500000000         72         145  Vega Baja Municipio, PR  2005
# 3218  CN7214700000000         72         147    Vieques Municipio, PR  2005
# 3219  CN7214900000000         72         149   Villalba Municipio, PR  2005
# 3220  CN7215100000000         72         151    Yabucoa Municipio, PR  2005
# 3221  CN7215300000000         72         153      Yauco Municipio, PR  2005
#
#       labor_force  employed  unemployed  unemployment_rate   fips
# 5           23887     22986         901                3.8  01001
# 6           76608     73581        3027                4.0  01003
# 7           10730     10114         616                5.7  01005
# 8            8837      8444         393                4.4  01007
# 9           26378     25434         944                3.6  01009
# ...           ...       ...         ...                ...    ...
# 3217        20930     18296        2634               12.6  72145
# 3218         3062      2725         337               11.0  72147
# 3219         9506      8112        1394               14.7  72149
# 3220        11247      9272        1975               17.6  72151
# 3221        16695     14380        2315               13.9  72153
#
# [3217 rows x 10 columns]

# %%
print(pd.io.sql.get_schema(df, "us_employment_data"))
# Out:
# CREATE TABLE "us_employment_data" (
# "LAUS_code" TEXT,
#   "state_fips" TEXT,
#   "county_fips" TEXT,
#   "county_state" TEXT,
#   "year" TEXT,
#   "labor_force" INTEGER,
#   "employed" INTEGER,
#   "unemployed" INTEGER,
#   "unemployment_rate" REAL,
#   "fips" TEXT
# )

# %%
df.year = pd.to_numeric(df.year)
df.unemployment_rate = pd.to_numeric(df.unemployment_rate)

# %%
print(pd.io.sql.get_schema(df, "us_employment_data"))
# Out:
# CREATE TABLE "us_employment_data" (
# "LAUS_code" TEXT,
#   "state_fips" TEXT,
#   "county_fips" TEXT,
#   "county_state" TEXT,
#   "year" INTEGER,
#   "labor_force" INTEGER,
#   "employed" INTEGER,
#   "unemployed" INTEGER,
#   "unemployment_rate" REAL,
#   "fips" TEXT
# )

# %%
df.to_csv(f"/Users/alvin/Documents/projects/project_de-zoomcamp/01-ingestion/data/us_employment_{df.year[6]}.csv", index=None, header=True)

# %%
df_csv = pd.DataFrame(pd.read_csv(f"/Users/alvin/Documents/projects/project_de-zoomcamp/01-ingestion/data/us_employment_{df.year[6]}.csv"))

# %%
df_csv
# Out:
#             LAUS_code  state_fips  county_fips             county_state  year  \
# 0     CN0100100000000           1            1       Autauga County, AL  2005
# 1     CN0100300000000           1            3       Baldwin County, AL  2005
# 2     CN0100500000000           1            5       Barbour County, AL  2005
# 3     CN0100700000000           1            7          Bibb County, AL  2005
# 4     CN0100900000000           1            9        Blount County, AL  2005
# ...               ...         ...          ...                      ...   ...
# 3212  CN7214500000000          72          145  Vega Baja Municipio, PR  2005
# 3213  CN7214700000000          72          147    Vieques Municipio, PR  2005
# 3214  CN7214900000000          72          149   Villalba Municipio, PR  2005
# 3215  CN7215100000000          72          151    Yabucoa Municipio, PR  2005
# 3216  CN7215300000000          72          153      Yauco Municipio, PR  2005
#
#       labor_force  employed  unemployed  unemployment_rate   fips
# 0           23887     22986         901                3.8   1001
# 1           76608     73581        3027                4.0   1003
# 2           10730     10114         616                5.7   1005
# 3            8837      8444         393                4.4   1007
# 4           26378     25434         944                3.6   1009
# ...           ...       ...         ...                ...    ...
# 3212        20930     18296        2634               12.6  72145
# 3213         3062      2725         337               11.0  72147
# 3214         9506      8112        1394               14.7  72149
# 3215        11247      9272        1975               17.6  72151
# 3216        16695     14380        2315               13.9  72153
#
# [3217 rows x 10 columns]
